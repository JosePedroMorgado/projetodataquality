# %%
# Importa o módulo
from data_quality import DataQuality
import pandas as pd


# Carrega um DataFrame (exemplo com o dataset Titanic)
df = pd.read_csv('C:/Users/José Pedro Morgado/Desktop/aula/penguins.csv')

# Crie uma instância de DataQuality
dq = DataQuality(df)

# Gere o relatório
relatorio = dq.generate_report()

# Imprima o relatório
print(relatorio)
# Out:
# === Relatório de Qualidade de Dados ===
#
# 1. Contagem de valores ausentes:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64
#
# 2. Contagem de valores únicos:
# species                3
# island                 3
# bill_length_mm       164
# bill_depth_mm         80
# flipper_length_mm     55
# body_mass_g           94
# sex                    2
# dtype: int64
#
# 3. Contagem de valores de texto únicos:
# species    3
# island     3
# sex        2
# dtype: int64
#
# 4. Contagem de valores float únicos:
# bill_length_mm       164
# bill_depth_mm         80
# flipper_length_mm     55
# body_mass_g           94
# dtype: int64
#
# 5. Contagem de valores inteiros únicos:
# Series([], dtype: object)
#
# 6. Contagem de valores para colunas categóricas:
#
# Contagem de valores para species:
# species
# Adelie       152
# Gentoo       124
# ...
